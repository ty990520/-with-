# %% [markdown]
# # 막대그래프 그리기

# %%
import csv
f=open('age.csv')
data=csv.reader(f)
next(data)
result=[]

for row in data:
    if '연수구' in row[0] and '송도' in row[0]:
        for i in row[3:]:
            result.append(int(i.replace(',','')))

print(len(result))
import matplotlib.pyplot as plt
#plt.bar(막대를 표시할 위치, 막대의 높이)
plt.bar(range(404),result)
plt.show()
# Out:
# 404

# %%
import csv
f=open('age.csv')
data=csv.reader(f)
next(data)
result=[]

for row in data:
    if '연수구' in row[0] and '송도' in row[0]:
        for i in row[3:]:
            result.append(int(i.replace(',','')))

print(len(result))
import matplotlib.pyplot as plt
#plt.barh(막대를 표시할 위치, 막대의 높이)
plt.barh(range(404),result)
plt.show()
# Out:
# 404

# %%
import csv
f=open('gender.csv')
data=csv.reader(f)
next(data)
m=[]
f=[]

for row in data:
    if '연수구' in row[0] and '송도' in row[0]:
        for i in range(0,101):
            m.append(int(row[i+3]))
            f.append(int(row[-(i+1)]))

f.reverse() #리스트의 값을 역순으로 재배열하는 함수
print(m)
print(f)
# Out:
# [102, 104, 119, 145, 158, 177, 179, 207, 222, 247, 233, 270, 330, 288, 228, 277, 277, 261, 284, 308, 302, 298, 290, 286, 332, 308, 274, 329, 301, 251, 214, 198, 170, 185, 190, 178, 200, 201, 220, 232, 279, 251, 248, 281, 272, 334, 380, 323, 364, 360, 368, 356, 309, 320, 320, 322, 273, 297, 285, 269, 289, 264, 212, 179, 165, 178, 125, 122, 106, 53, 94, 79, 53, 70, 49, 50, 41, 50, 48, 45, 33, 31, 18, 20, 14, 12, 13, 12, 5, 2, 6, 4, 7, 2, 2, 1, 1, 0, 2, 0, 0, 114, 112, 173, 228, 229, 269, 348, 337, 358, 338, 358, 373, 379, 364, 299, 291, 298, 296, 273, 309, 258, 210, 202, 198, 176, 178, 181, 186, 152, 134, 145, 117, 131, 126, 148, 174, 198, 265, 320, 293, 347, 361, 397, 382, 415, 399, 418, 432, 444, 431, 376, 396, 342, 288, 277, 243, 242, 252, 232, 220, 199, 168, 158, 130, 115, 120, 54, 60, 59, 33, 39, 49, 37, 50, 25, 23, 27, 43, 23, 23, 29, 13, 10, 17, 16, 13, 9, 6, 4, 2, 2, 2, 3, 2, 1, 2, 2, 0, 0, 1, 0, 289, 324, 307, 345, 406, 407, 373, 435, 403, 408, 362, 338, 361, 350, 298, 267, 23
# ...

# %%
import csv
f=open('gender.csv')
data=csv.reader(f)
next(data)
m=[]
f=[]

for row in data:
    if '연수구' in row[0] and '송도' in row[0]:
        for i in row[3:104]:
            m.append(int(i))
        for i in row[106:]:
            f.append(int(i))
print(len(m))
print(len(f))
# Out:
# 404
# 404

# %%
import matplotlib.pyplot as plt
import csv
f=open('gender.csv')
data=csv.reader(f)
next(data)
m=[]
f=[]

for row in data:
    if '신도림' in row[0]:
        for i in row[3:104]:
            m.append(int(i.replace(',','')))
        for i in row[106:]:
            f.append(int(i.replace(',','')))

            
plt.barh(range(len(m)),m)
plt.barh(range(len(f)),f)
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
f=open('gender.csv')
data=csv.reader(f)
next(data)
m=[]
f=[]

for row in data:
    if '신도림' in row[0]:
        for i in row[3:104]:
            m.append(-int(i))
        for i in row[106:]:
            f.append(int(i))

plt.rc('font',family='Malgun Gothic')
plt.rcParams['axes.unicode_minus']=False
plt.title('신도림 지역의 남녀 성별 인구 분포')            
plt.barh(range(len(m)),m,label='남성')
plt.barh(range(len(f)),f,label='여성')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
f=open('gender.csv')
data=csv.reader(f)
next(data)
m=[]
f=[]
name=input('찾고 싶은 지역의 이름을 입력하세요:')

for row in data:
    if name in row[0]:
        for i in row[3:104]:
            m.append(-int(i.replace(',','')))
        for i in row[106:]:
            f.append(int(i.replace(',','')))
            
plt.style.use('ggplot')
plt.figure(figsize=(5,3),dpi=100)
plt.rc('font',family='Malgun Gothic')
plt.rcParams['axes.unicode_minus']=False
plt.title(name+' 지역의 남녀 성별 인구 분포')            
plt.barh(range(len(m)),m,label='남성')
plt.barh(range(len(f)),f,label='여성')
plt.legend()
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 입력하세요:송도3동
